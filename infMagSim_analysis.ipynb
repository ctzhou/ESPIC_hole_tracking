# %%
from math import *
import numpy as np
import matplotlib
import bisect
import sys
import glob
matplotlib.use('Qt4Agg') # GUI backend
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib.widgets import Slider
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
from functools import partial
import IPython.core.display as IPdisp

# %%
folder = "/scratch/chaako/fromLoki/lineSim*/"
file_names = glob.glob(folder + "l*.npz")
file_names.sort()
i=0
for file_name in file_names:
    print i, file_name
    i += 1
# Out:
# 0 /scratch/chaako/fromLoki/lineSim004/l0.2500_d0.125_np1.0e+04_ni1.0e+05_dt5.8e-04.npz
# 1 /scratch/chaako/fromLoki/lineSim005/l0.2500_d0.125_np1.0e+04_ni6.0e+05_dt5.8e-04.npz
# 2 /scratch/chaako/fromLoki/lineSim006/l0.2500_d0.125_np1.0e+04_ni1.0e+05_dt5.8e-04.npz
# 3 /scratch/chaako/fromLoki/lineSim007/l0.2500_d0.125_np1.0e+04_ni1.0e+05_dt2.9e-04.npz
# 4 /scratch/chaako/fromLoki/lineSim008/l0.2500_d0.125_np1.0e+03_ni1.0e+05_dt5.8e-04.npz
# 5 /scratch/chaako/fromLoki/lineSim009/l0.2500_d0.125_np4.0e+04_ni1.0e+05_dt5.8e-04.npz
# 6 /scratch/chaako/fromLoki/lineSim010/l0.2500_d0.125_np1.0e+03_ni1.0e+05_dt5.8e-04.npz
# 7 /scratch/chaako/fromLoki/lineSim011/l0.2500_d0.125_np1.0e+03_ni1.0e+05_dt5.8e-04.npz
# 8 /scratch/chaako/fromLoki/lineSim012/l0.2500_d0.125_np1.0e+03_ni1.0e+05_dt5.8e-04.npz
# 9 /scratch/chaako/fromLoki/lineSim013/l0.2500_d0.125_np1.0e+03_ni1.0e+05_dt5.8e-04.npz
# 10 /scratch/chaako/fromLoki/lineSim014/l0.2500_d0.125_np1.0e+03_ni1.0e+05_dt5.8e-04.npz
# 11 /scratch/chaako/fromLoki/lineSim015/l0.2500_d0.125_np1.0e+03_ni1.0e+05_dt5.8e-04.npz
# 12 /scratch/chaako/fromLoki/lineSim016/l1.0000_d0.125_np1.0e+03_ni1.0e+05_dt2.3e-03.npz
# 13 /scratch/chaako/fromLoki/lineSim017/l1.0000_d0.125_np1.0e+03_ni1.0e+05_dt2.3e-03.npz
# 14 /scratch/chaako/fromLoki/lineSim018/l0.0100_d0.125_np1.0e+04_ni1.0e+05_dt2.3e-05.npz
# 15 /scratch/chaako/fromLoki/lineSim019/l0.0100_d0.125_np1.0e+04_ni4.0e+05_dt2.3e-05.npz
# 16 /scratch/chaako/fromLoki/lineSim020/l0.0100_d0.125_np1.0e+04_ni1.5e+05_dt2.3e-05.npz
# 17 /scratch/chaako/fromLoki/lineSim021/l0.0100_d0.125_np1.0e+04_ni1.5e+05_dt2.3e-05.npz
# 18 /scratch/chaako/fromLoki/lineSim022/l0.0400_d0.125_np1.0e+04_ni1.5e+05_dt9.3e-05.npz
# 19 /scratch/chaako/fromLoki/lineSim023/l0.0400_d0.125_np1.0e+04_ni1.5e+05_dt9.3e-05.npz
# 20 /scratch/chaako/fromLoki/lineSim024/l0.0400_d0.125_np1.0e+04_ni1.5e+05_dt9.3e-05.npz
# 21 /scratch/chaako/fromLoki/lineSim025/l0.0400_d0.125_np1.0e+04_ni1.5e+05_dt9.3e-05.npz
# 22 /scratch/chaako/fromLoki/lineSim026/l0.0400_d0.125_np1.0e+04_ni1.5e+05_dt9.3e-05.npz
# 23 /scratch/chaako/fromLoki/lineSim027/l0.0400_d0.125_np1.0e+04_ni5.0e+04_dt9.3e-05.npz
# 24 /scratch/chaako/fromLoki/lineSim028/l0.0400_d0.125_np5.0e+02_ni1.5e+05_dt2.0e-03.npz
# 25 /scratch/chaako/fromLoki/lineSim029/l0.0400_d0.125_np1.0e+04_ni5.0e+04_dt2.0e-03.npz
# 26 /scratch/chaako/fromLoki/lineSim030/l0.0400_d0.125_np1.0e+04_ni5.0e+04_dt2.0e-03.npz
# 27 /scratch/chaako/fromLoki/lineSim031/l0.0400_d0.125_np1.0e+04_ni1.5e+05_dt2.0e-03.npz
# 28 /scratch/chaako/fromLoki/lineSim032/l0.0400_d0.125_np1.0e+04_ni1.5e+05_dt3.7e-04.npz
# 29 /scratch/chaako/fromLoki/lineSim033/l0.0400_d0.125_np1.0e+04_ni1.5e+05_dt1.5e-03.npz
# 30 /scratch/chaako/fromLoki/lineSim034/l0.0400_d0.125_np1.0e+04_ni1.5e+05_dt7.5e-04.npz
# 31 /scratch/chaako/fromLoki/lineSim035/l0.0400_d0.125_np1.0e+04_ni1.5e+05_dt3.7e-04.npz
# 32 /scratch/chaako/fromLoki/lineSim036/l0.0400_d0.125_np1.0e+04_ni1.5e+05_dt1.9e-04.npz
# 33 /scratch/chaako/fromLoki/lineSim037/l0.0200_d0.125_np1.0e+04_ni1.5e+05_dt9.3e-05.npz
# 34 /scratch/chaako/fromLoki/lineSim038/l0.0400_d0.125_np1.0e+04_ni1.5e+05_dt2.0e-03.npz
# 35 /scratch/chaako/fromLoki/lineSim039/l0.0200_d0.125_np1.0e+04_ni1.5e+05_dt1.0e-03.npz
# 36 /scratch/chaako/fromLoki/lineSim040/l0.0400_d0.125_np1.0e+04_ni7.5e+04_dt2.0e-03.npz
# 37 /scratch/chaako/fromLoki/lineSim041/l0.0400_d0.125_np1.0e+04_ni1.5e+05_dt1.0e-03.npz
# 38 /scratch/chaako/fromLoki/lineSim042/l0.0800_d0.125_np1.0e+04_ni1.5e+05_dt3.7e-04.npz
# 39 /scratch/chaako/fromLoki/lineSim043/l0.0100_d0.125_np1.0e+04_ni1.5e+05_dt5.0e-04.npz
# 40 /scratch/chaako/fromLoki/lineSim044/l0.0200_d0.125_np1.0e+04_ni3.0e+05_dt9.3e-05.npz
# 41 /scratch/chaako/fromLoki/lineSim045/l0.0100_d0.125_np1.0e+04_ni6.0e+05_dt5.0e-04.npz
# 42 /scratch/chaako/fromLoki/lineSim046/l0.0800_d0.125_np1.0e+04_ni5.0e+04_dt3.7e-04.npz
# 43 /scratch/chaako/fromLoki/lineSim047/l0.0025_d0.125_np4.0e+04_ni6.0e+05_dt1.3e-04.npz
# 44 /scratch/chaako/fromLoki/lineSim048/l0.0013_d0.125_np4.0e+04_ni1.2e+06_dt6.3e-05.npz
# 45 /scratch/chaako/fromLoki/lineSim049/l0.0025_d0.125_np4.0e+04_ni6.0e+05_dt1.3e-04.npz
# 46 /scratch/chaako/fromLoki/lineSim050/l0.0025_d0.125_np4.0e+04_ni6.0e+05_dt1.3e-04.npz
# 47 /scratch/chaako/fromLoki/lineSim051/l0.0013_d0.125_np4.0e+04_ni6.0e+05_dt6.3e-05.npz
# 48 /scratch/chaako/fromLoki/lineSim052/l0.0050_d0.125_np4.0e+04_ni6.0e+05_dt2.5e-04.npz
# 49 /scratch/chaako/fromLoki/lineSim053/l0.0100_d0.125_np4.0e+04_ni6.0e+05_dt5.0e-04.npz
# 50 /scratch/chaako/fromLoki/lineSim054/l0.0200_d0.125_np4.0e+04_ni6.0e+05_dt1.0e-03.npz
# 51 /scratch/chaako/fromLoki/lineSim055/l0.0400_d0.125_np4.0e+04_ni6.0e+05_dt2.0e-03.npz
# 52 /scratch/chaako/fromLoki/lineSim056/l0.0800_d0.125_np4.0e+04_ni6.0e+05_dt4.0e-03.npz
# 53 /scratch/chaako/fromLoki/lineSim057/l0.0800_d0.125_np4.0e+04_ni6.0e+05_dt4.0e-03.npz
# 54 /scratch/chaako/fromLoki/lineSim058/l0.0400_d0.125_np1.0e+04_ni1.5e+05_dt8.9e-04.npz
# 55 /scratch/chaako/fromLoki/lineSim059/l0.0400_d0.125_np1.0e+04_ni1.5e+05_dt9.3e-05.npz
# 56 /scratch/chaako/fromLoki/lineSim060/l0.0400_d0.125_np1.0e+04_ni1.5e+05_dt8.9e-04.npz
# 57 /scratch/chaako/fromLoki/lineSim061/l0.0200_d0.125_np1.0e+04_ni1.5e+05_dt4.5e-04.npz
# 58 /scratch/chaako/fromLoki/lineSim062/l0.0100_d0.125_np1.0e+04_ni1.5e+05_dt2.2e-04.npz
# 59 /scratch/chaako/fromLoki/lineSim063/l0.0200_d0.125_np1.0e+04_ni1.5e+05_dt4.7e-05.npz
# 60 /scratch/chaako/fromLoki/lineSim064/l0.0100_d0.125_np1.0e+04_ni1.5e+05_dt2.3e-05.npz
# 61 /scratch/chaako/fromLoki/lineSim065/l0.0400_d0.125_np1.0e+04_ni3.8e+04_dt8.9e-04.npz
# 62 /scratch/chaako/fromLoki/lineSim066/l0.0100_d0.125_np1.0e+04_ni6.0e+05_dt2.3e-05.npz
# 63 /scratch/chaako/fromLoki/lineSim067/l0.0050_d0.125_np1.0e+04_ni3.0e+05_dt1.2e-05.npz
# 64 /scratch/chaako/fromLoki/lineSim068/l0.0400_d0.125_np1.0e+04_ni1.5e+05_dt3.7e-04.npz
# 65 /scratch/chaako/fromLoki/lineSim069/l0.0400_d0.125_np1.0e+04_ni1.5e+05_dt3.7e-04.npz
# 66 /scratch/chaako/fromLoki/lineSim070/l0.1600_d0.125_np1.0e+04_ni1.5e+05_dt1.5e-03.npz
# 67 /scratch/chaako/fromLoki/lineSim071/l0.3200_d0.125_np1.0e+04_ni1.5e+05_dt3.0e-03.npz
# 68 /scratch/chaako/fromLoki/lineSim072/l0.0100_d0.125_np1.0e+04_ni1.5e+05_dt9.3e-05.npz
# 69 /scratch/chaako/fromLoki/lineSim074/l0.0800_d0.125_np1.0e+04_ni1.5e+05_dt7.5e-04.npz
# 70 /scratch/chaako/fromLoki/lineSim075/l0.1600_d0.125_np1.0e+04_ni1.5e+05_dt7.5e-04.npz
# 71 /scratch/chaako/fromLoki/lineSim076/l0.0800_d0.125_np1.0e+04_ni1.5e+05_dt3.7e-04.npz
# 72 /scratch/chaako/fromLoki/lineSim077/l0.0400_d0.125_np1.0e+04_ni1.5e+05_dt1.9e-04.npz
# 73 /scratch/chaako/fromLoki/lineSim078/l0.0200_d0.125_np1.0e+04_ni1.5e+05_dt9.3e-05.npz
# 74 /scratch/chaako/fromLoki/lineSim079/l0.0200_d0.125_np1.0e+04_ni1.5e+05_dt1.9e-04.npz
# 75 /scratch/chaako/fromLoki/lineSim080/l0.0800_d0.125_np1.0e+04_ni1.5e+05_dt1.9e-04.npz
# 76 /scratch/chaako/fromLoki/lineSim081/l0.0050_d0.125_np1.0e+04_ni1.5e+05_dt2.3e-05.npz
# 77 /scratch/chaako/fromLoki/lineSim082/l0.0050_d0.125_np1.0e+04_ni6.0e+05_dt2.3e-05.npz
# 78 /scratch/chaako/fromLoki/lineSim083/l0.0050_d0.125_np5.0e+03_ni3.0e+05_dt1.2e-05.npz
# 79 /scratch/chaako/fromLoki/lineSim084/l0.1600_d0.125_np5.0e+03_ni9.6e+06_dt3.7e-04.npz
# 80 /scratch/chaako/fromLoki/lineSim085/l0.0160_d0.125_np5.0e+03_ni3.0e+05_dt3.7e-05.npz
# 81 /scratch/chaako/fromLoki/lineSim086/l0.1600_d0.125_np5.0e+03_ni9.6e+06_dt3.7e-04.npz
# 82 /scratch/chaako/fromLoki/lineSim087/l0.1600_d0.125_np5.0e+03_ni9.6e+06_dt3.7e-04.npz
# 83 /scratch/chaako/fromLoki/lineSim088/l0.0160_d0.125_np5.0e+03_ni1.5e+05_dt3.7e-05.npz
# 84 /scratch/chaako/fromLoki/lineSim089/l0.0160_d0.125_np5.0e+03_ni9.6e+06_dt3.7e-05.npz
# 85 /scratch/chaako/fromLoki/lineSim090/l0.0160_d0.125_np5.0e+03_ni9.6e+06_dt3.7e-05.npz
# 86 /scratch/chaako/fromLoki/lineSim091/l0.1600_d0.125_np5.0e+03_ni9.6e+06_dt3.7e-04.npz
# 87 /scratch/chaako/fromLoki/lineSim092/l0.1600_d0.125_np5.0e+03_ni9.6e+06_dt3.7e-04.npz
# 88 /scratch/chaako/fromLoki/lineSim093/l0.1600_d0.125_np5.0e+03_ni9.6e+06_dt3.7e-04.npz
# 89 /scratch/chaako/fromLoki/lineSim094/l0.0050_d0.125_np5.0e+03_ni1.9e+04_dt1.2e-05.npz
# 90 /scratch/chaako/fromLoki/lineSim095/l0.0050_d0.125_np5.0e+03_ni1.9e+04_dt1.2e-05.npz
# 91 /scratch/chaako/fromLoki/lineSim096/l0.0050_d0.125_np5.0e+03_ni1.9e+04_dt1.2e-05.npz
# 92 /scratch/chaako/fromLoki/lineSim097/l0.0050_d0.125_np5.0e+03_ni1.5e+05_dt1.2e-05.npz
# 93 /scratch/chaako/fromLoki/lineSim098/l0.0050_d0.125_np5.0e+03_ni1.5e+05_dt1.2e-05.npz
# 94 /scratch/chaako/fromLoki/lineSim099/l0.0050_d0.125_np5.0e+03_ni1.5e+05_dt1.2e-05.npz
# 95 /scratch/chaako/fromLoki/lineSim100/l0.0013_d0.125_np2.0e+04_ni1.5e+05_dt1.2e-05.npz
# 96 /scratch/chaako/fromLoki/lineSim101/l0.0013_d0.125_np2.0e+04_ni1.5e+05_dt1.2e-05.npz
# 97 /scratch/chaako/fromLoki/lineSim102/l0.0013_d0.125_np2.0e+04_ni2.4e+06_dt1.2e-05.npz
# 98 /scratch/chaako/fromLoki/lineSim103/l0.0013_d0.125_np2.0e+04_ni1.5e+05_dt1.2e-05.npz
# 99 /scratch/chaako/fromLoki/lineSim104/l0.0013_d0.125_np2.0e+04_ni1.5e+05_dt1.2e-05.npz
# 100 /scratch/chaako/fromLoki/lineSim105/l0.0013_d0.125_np2.0e+04_ni9.6e+06_dt1.2e-05.npz
# 101 /scratch/chaako/fromLoki/lineSim106/l0.0013_d0.125_np2.0e+04_ni9.6e+06_dt1.2e-05.npz
# 102 /scratch/chaako/fromLoki/lineSim107/l0.0013_d0.125_np2.0e+04_ni1.5e+05_dt1.2e-05.npz
# 103 /scratch/chaako/fromLoki/lineSim108/l0.0013_d0.125_np2.0e+04_ni1.5e+05_dt1.2e-05.npz
# 104 /scratch/chaako/fromLoki/lineSim109/l0.0013_d0.125_np2.0e+04_ni1.5e+05_dt1.2e-05.npz
# 105 /scratch/chaako/fromLoki/lineSim111/l0.0013_d0.125_np2.0e+04_ni1.5e+05_dt1.2e-05.npz
# 106 /scratch/chaako/fromLoki/lineSim112/l0.0013_d0.125_np2.0e+04_ni7.5e+05_dt1.2e-05.npz
# 107 /scratch/chaako/fromLoki/lineSim113/l0.0013_d0.125_np2.0e+04_ni2.4e+06_dt1.2e-05.npz
# 108 /scratch/chaako/fromLoki/lineSim114/l0.0025_d0.125_np2.0e+04_ni2.4e+06_dt4.7e-05.npz
# 109 /scratch/chaako/fromLoki/lineSim115/l0.0025_d0.125_np2.0e+04_ni2.4e+06_dt4.7e-05.npz
# 110 /scratch/chaako/fromLoki/lineSim116/l0.0025_d0.125_np2.0e+04_ni2.4e+06_dt4.7e-05.npz
# 111 /scratch/chaako/fromLoki/lineSim117/l0.0013_d0.125_np2.0e+04_ni2.4e+06_dt2.3e-05.npz
# 112 /scratch/chaako/fromLoki/lineSim118/l0.0013_d0.125_np2.0e+04_ni4.8e+06_dt2.3e-05.npz
# 113 /scratch/chaako/fromLoki/lineSim119/l0.0013_d0.125_np2.0e+04_ni4.8e+06_dt4.7e-05.npz
# 114 /scratch/chaako/fromLoki/lineSim120/l0.0025_d0.125_np2.0e+04_ni4.8e+06_dt9.3e-05.npz
# 115 /scratch/chaako/fromLoki/lineSim121/l0.0050_d0.125_np2.0e+04_ni4.8e+06_dt1.9e-04.npz
# 116 /scratch/chaako/fromLoki/lineSim122/l0.0050_d0.125_np5.0e+03_ni1.5e+05_dt2.3e-05.npz
# 117 /scratch/chaako/fromLoki/lineSim123/l0.0050_d0.125_np1.0e+04_ni1.5e+05_dt2.3e-05.npz
# 118 /scratch/chaako/fromLoki/lineSim124/l0.0050_d0.125_np1.0e+04_ni1.5e+05_dt2.3e-05.npz
# 119 /scratch/chaako/fromLoki/lineSim125/l0.0050_d0.125_np1.0e+04_ni1.5e+05_dt2.3e-05.npz
# 120 /scratch/chaako/fromLoki/lineSim126/l0.0100_d0.125_np1.0e+04_ni2.4e+06_dt3.7e-04.npz
# 121 /scratch/chaako/fromLoki/lineSim127/l0.0100_d0.125_np1.0e+04_ni2.4e+06_dt3.7e-04.npz
# 122 /scratch/chaako/fromLoki/lineSim128/l0.0013_d0.125_np4.0e+04_ni2.4e+06_dt1.3e-04.npz
# 123 /scratch/chaako/fromLoki/lineSim129/l0.0025_d0.125_np4.0e+04_ni2.4e+06_dt2.5e-04.npz
# 124 /scratch/chaako/fromLoki/lineSim130/l0.0050_d0.125_np4.0e+04_ni2.4e+06_dt5.0e-04.npz
# 125 /scratch/chaako/fromLoki/lineSim131/l0.0100_d0.125_np4.0e+04_ni2.4e+06_dt1.0e-03.npz
# 126 /scratch/chaako/fromLoki/lineSim132/l0.0200_d0.125_np4.0e+04_ni2.4e+06_dt2.0e-03.npz
# 127 /scratch/chaako/fromLoki/lineSim133/l0.0400_d0.125_np4.0e+04_ni2.4e+06_dt4.0e-03.npz
# 128 /scratch/chaako/fromLoki/lineSim134/l0.0800_d0.125_np4.0e+04_ni2.4e+06_dt8.0e-03.npz
# 129 /scratch/chaako/fromLoki/lineSim135/l0.0400_d0.125_np4.0e+04_ni2.4e+06_dt4.0e-03.npz
# 130 /scratch/chaako/fromLoki/lineSim136/l0.0800_d0.125_np4.0e+04_ni2.4e+06_dt8.0e-03.npz
# 131 /scratch/chaako/fromLoki/lineSim137/l0.0100_d0.125_np1.0e+04_ni2.4e+06_dt8.9e-04.npz
# 132 /scratch/chaako/fromLoki/lineSim138/l0.0200_d0.125_np4.0e+04_ni2.4e+06_dt2.0e-03.npz
# 133 /scratch/chaako/fromLoki/lineSim139/l0.0013_d0.125_np2.0e+04_ni2.4e+06_dt1.2e-05.npz
# 134 /scratch/chaako/fromLoki/lineSim140/l0.0025_d0.125_np2.0e+04_ni6.0e+05_dt2.3e-05.npz
# 135 /scratch/chaako/fromLoki/lineSim141/l0.0025_d0.125_np2.0e+04_ni2.4e+06_dt2.3e-05.npz
# 136 /scratch/chaako/fromLoki/lineSim142/l0.0050_d0.125_np2.0e+04_ni1.2e+06_dt9.3e-05.npz
# 137 /scratch/chaako/fromLoki/lineSim143/l0.0003_d0.125_np4.0e+04_ni3.0e+05_dt5.8e-06.npz
# 138 /scratch/chaako/fromLoki/lineSim144/l0.0013_d0.125_np2.0e+04_ni1.2e+06_dt1.2e-05.npz
# 139 /scratch/chaako/fromLoki/lineSim145/l0.0050_d0.125_np2.0e+04_ni1.2e+06_dt9.3e-05.npz
# 140 /scratch/chaako/fromLoki/lineSim146/l0.0050_d0.125_np2.0e+04_ni1.2e+06_dt4.7e-05.npz
# 141 /scratch/chaako/fromLoki/lineSim147/l0.0050_d0.125_np2.0e+04_ni1.2e+06_dt4.7e-05.npz
# 142 /scratch/chaako/fromLoki/lineSim148/l0.0025_d0.125_np2.0e+04_ni1.2e+06_dt4.7e-05.npz
# 143 /scratch/chaako/fromLoki/lineSim149/l0.0050_d0.125_np2.0e+04_ni1.2e+06_dt9.3e-05.npz
# 144 /scratch/chaako/fromLoki/lineSim150/l0.0050_d0.125_np2.0e+04_ni1.2e+06_dt9.3e-05.npz
# 145 /scratch/chaako/fromLoki/lineSim151/l0.0050_d0.125_np2.0e+04_ni1.2e+06_dt4.7e-05.npz

# %%
file_index = -1

#plot_dist_func = False
plot_dist_func = True
file_name = file_names[file_index]
data_file = np.load(file_name)
print data_file.files
grid = data_file['grid']
times = data_file['times']
ion_densities = data_file['ion_densities']
electron_densities = data_file['electron_densities']
#charge_derivatives = data_file['charge_derivatives']
potentials = data_file['potentials']
#potentials_electrons = data_file['potentials_electrons']
if file_index>82:
    electric_fields = data_file['electric_fields']
else:
    electric_fields = potentials
object_masks = data_file['object_masks']
if plot_dist_func:
    ion_hist_n_edges = data_file['ion_hist_n_edges']
    ion_hist_v_edges = data_file['ion_hist_v_edges']
    ion_distribution_functions = data_file['ion_distribution_functions']
    electron_hist_n_edges = data_file['electron_hist_n_edges']
    electron_hist_v_edges = data_file['electron_hist_v_edges']
    electron_distribution_functions = data_file['electron_distribution_functions']
    background_ion_density = data_file['background_ion_density']
    background_electron_density = data_file['background_electron_density']
# Out:
# ['ion_hist_v_edges', 'ion_hist_n_edges', 'background_electron_density', 'charge_derivatives', 'electric_fields', 'electron_densities', 'times', 'potentials_electrons', 'background_ion_density', 'grid', 'electron_distribution_functions', 'potentials', 'electron_hist_v_edges', 'ion_distribution_functions', 'electron_hist_n_edges', 'ion_densities', 'object_masks']

# %%
def slider_changed(new_value, data_arrays, plots, fig, times=[], texts=[]):
    k = int(new_value)
    for plot, data in zip(plots,data_arrays):
	plot.set_ydata(data[k])
    for txt in texts:
        txt.set_text("t = {0}".format(times[k]))
    fig.canvas.draw()

def arrow_pressed(event, data_arrays, plots, fig, slider, times=[], texts=[]):
    value = slider.val
    if (event.key=='left' or event.key=='4'):
	value -= 1
    elif (event.key=='right' or event.key=='6'):
	value += 1
    elif (event.key=='down' or event.key=='5'):
	value -= 1
    elif (event.key=='up' or event.key=='8'):
	value += 1
    slider.set_val(value)
    slider_changed(value, data_arrays, plots, fig, times, texts)

k = len(times)-1
print times[k]
fig = plt.figure(figsize=(18,8))
gs = gridspec.GridSpec(4, 3, height_ratios=[16,16,1,1])
axes = []
plots = []
if plot_dist_func:
    if len(electron_distribution_functions)>0:
	x_axes = [grid, ion_hist_v_edges[:-1], electron_hist_v_edges[:-1], grid, grid, grid, grid]
    else:
	x_axes = [grid, ion_hist_v_edges[:-1], ion_hist_v_edges[:-1], grid, grid, grid, grid]
else:
    x_axes = [grid, grid, grid, grid, grid, grid, grid]
if plot_dist_func:
    if len(electron_distribution_functions)>0:
	data_arrays = [potentials, \
			   np.squeeze(ion_distribution_functions[:,(ion_distribution_functions.shape[1]-1)*4./8.,:]), \
			   np.squeeze(electron_distribution_functions[:,(electron_distribution_functions.shape[1]-1)*4./8.,:]), \
#			   electric_fields, ion_densities, electron_densities]
			   ion_densities-electron_densities, ion_densities, electron_densities]
	#offset = 47
	#offset = 160
	#offset = 280
	#data_arrays = [potentials, \
	#		   np.squeeze(ion_distribution_functions[:,(len(grid)/2+offset)/10,:]), \
	#		   (np.squeeze(electron_distribution_functions[:,(len(grid)/2+offset)/10,:])).copy(), \
	#		   ion_densities-electron_densities, ion_densities, electron_densities]
	#electron_distribution_functions[:,(len(grid)/2+offset)/10,:] = 0
    else:
	data_arrays = [potentials, \
			   np.squeeze(ion_distribution_functions[:,(ion_distribution_functions.shape[1]-1)*5./8.,:]), \
			   np.squeeze(ion_distribution_functions[:,(ion_distribution_functions.shape[1]-1)*5./8.,:]), \
			   electric_fields, ion_densities, electron_densities]
#			   ion_densities-electron_densities, ion_densities, electron_densities]
else:
    data_arrays = [potentials, \
		       object_masks, object_masks, \
		       electric_fields, ion_densities, electron_densities]
#		       ion_densities-electron_densities, ion_densities, electron_densities]
#data_arrays = [potentials, ion_densities-electron_densities, object_masks, charge_derivatives, ion_densities, electron_densities]
ranges = []
for data in data_arrays:
    this_range = [np.nanmin(data[np.fabs(data)<np.inf]),np.nanmax(data[np.fabs(data)<np.inf])]
    #print this_range
    ranges.append(this_range)
for spec, data, this_range, x in zip(gs, data_arrays, ranges, x_axes):
    ax = plt.subplot(spec)
    ax.set_ylim(this_range)
    #ax.set_ylim([-5.1,5.1])
    axes.append(ax)
    if data.shape[1]==len(x):
	plot, = ax.plot(x,data[k])
    else:
	plot, = ax.plot(data[k])
    plots.append(plot)

texts = []
ax = plt.subplot(gs[2,:])
ax.axis('off')
txt = ax.text(0,0,"t = {0}".format(times[k]))
texts.append(txt)

ax = plt.subplot(gs[3,:])
slider = Slider(ax, 'k', 0, k, valinit=len(times)-1, color='#AAAAAA')
changed_function = partial(slider_changed, data_arrays=data_arrays, plots=plots, fig=fig, times=times, texts=texts)
slider.on_changed(changed_function)

arrow_pressed_function = partial(arrow_pressed, data_arrays=data_arrays, plots=plots, fig=fig, slider=slider, times=times, texts=texts)
fig.canvas.mpl_connect('key_press_event',arrow_pressed_function)

#plt.tight_layout()
plt.show()
# Out:
# 1.74774

# %%
def slider_changed(new_value, data_arrays, plots, fig, times, texts):
    k = int(new_value)
    for plot, data in zip(plots,data_arrays):
	plot.set_data(data[k].T)
    for txt in texts:
        txt.set_text("t = {0}".format(times[k]))
    fig.canvas.draw()

#k=len(times)-1
k=0
fig = plt.figure(figsize=(18,8))
gs = gridspec.GridSpec(4, 1, height_ratios=[16,16,1,1])
if len(electron_distribution_functions)>0:
    v_th_e = electron_hist_v_edges[-1]/4. # TODO: do this in less hacky way
    electron_bin_velocities = (electron_hist_v_edges[:-1]+electron_hist_v_edges[1:])/2.
    electron_maxwellian = np.ones_like(electron_distribution_functions)
    electron_maxwellian *= np.exp(-electron_bin_velocities*electron_bin_velocities/2./v_th_e/v_th_e)
    electron_maxwellian /= v_th_e*np.sqrt(2.*np.pi)
    electron_maxwellian *= np.sum(electron_distribution_functions,axis=2)[:,:,None]
    electron_maxwellian *= (electron_hist_v_edges[-1]-electron_hist_v_edges[0])/electron_hist_v_edges.shape[0]
    #data_arrays = [ion_distribution_functions, electron_distribution_functions]
    data_arrays = [ion_distribution_functions, electron_distribution_functions-electron_maxwellian]
else:
    data_arrays = [ion_distribution_functions, ion_distribution_functions]
plots = []
ax = plt.subplot(gs[0,0])
extent = [ion_hist_n_edges[0], ion_hist_n_edges[-1], ion_hist_v_edges[0], ion_hist_v_edges[-1] ]
im = ax.imshow(data_arrays[0][k].T,origin='lower',extent=extent,cmap='copper')
plots.append(im)
ax.set_aspect('auto')
ax.set_xlabel('$y\ [R_\mathrm{M}]$', fontsize=16)
ax.set_ylabel(r'$v_y\ [\frac{R_\mathrm{M}}{v_\mathrm{T\,i}}]$', fontsize=16)
cbar = fig.colorbar(im)
cbar.set_label(r'$\frac{f_\mathrm{e}}{f_\mathrm{e\,\infty}(0)}$', fontsize=16)
ax = plt.subplot(gs[1,0])
extent = [electron_hist_n_edges[0], electron_hist_n_edges[-1], electron_hist_v_edges[0], electron_hist_v_edges[-1] ]
im = ax.imshow(data_arrays[1][k].T,origin='lower',extent=extent,cmap='pink',vmin=np.amin(data_arrays[1])/8.,vmax=np.amax(data_arrays[1])/8.)
plots.append(im)
ax.set_aspect('auto')
fig.colorbar(im)

texts = []
ax = plt.subplot(gs[2,:])
ax.axis('off')
txt = ax.text(0,0,"t = {0}".format(times[k]))
texts.append(txt)

ax = plt.subplot(gs[3,:])
slider = Slider(ax, 'k', 0, len(times)-1, valinit=k, color='#AAAAAA')
changed_function = partial(slider_changed, data_arrays=data_arrays, plots=plots, fig=fig, times=times, texts=texts)
slider.on_changed(changed_function)

arrow_pressed_function = partial(arrow_pressed, data_arrays=data_arrays, plots=plots, fig=fig, slider=slider, times=times, texts=texts)
fig.canvas.mpl_connect('key_press_event',arrow_pressed_function)

plt.show()
